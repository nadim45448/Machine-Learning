# %% [markdown]
# ***Part 1: Loading data set from google drive and display the data set***

# %%
"""
Here I connect my google drive with my colab
"""
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
"""
Here we import panda to load our dataset
df=entire data set
My file extension is .csv that's why I write df=pd.read_csv()
"""
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Datasets/Salary.csv')
df.head() # this will print 1st 5 rows of dataset
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes

# %%
df.head(10) # This will print 1st 10 rows
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes

# %%
df.tail(5) # This will print last 5 rows
# Out:
#    Country   Age   Salary Purchased
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  38.0  67000.0       Yes

# %%
df[6:8] # This will print 6th to 7th rows. When we want to select specific rows the we can do this.
# Out:
#   Country   Age   Salary Purchased
# 6   Spain   NaN  52000.0        No
# 7  France  48.0  79000.0       Yes

# %%
df['Country'] # this will print only the country column
# Out:
# 0     France
# 1      Spain
# 2    Germany
# 3      Spain
# 4    Germany
# 5     France
# 6      Spain
# 7     France
# 8    Germany
# 9     France
# Name: Country, dtype: object

# %%
df['Country'].head() #show first 5 sample of column country
# Out:
# 0     France
# 1      Spain
# 2    Germany
# 3      Spain
# 4    Germany
# Name: Country, dtype: object

# %%
df.loc[(df.Country=='France')] # All france information
# Out:
#   Country   Age   Salary Purchased
# 0  France  44.0  72000.0        No
# 5  France  35.0  58000.0       Yes
# 7  France  48.0  79000.0       Yes
# 9  France  38.0  67000.0       Yes

# %%
df.loc[(df.Country=='France') &(df.Age>35)] #All 35+ years & country France
# Out:
#   Country   Age   Salary Purchased
# 0  France  44.0  72000.0        No
# 7  France  48.0  79000.0       Yes
# 9  France  38.0  67000.0       Yes

# %%
df.iloc[[0,5]]#Print index 0 & 5
# Out:
#   Country   Age   Salary Purchased
# 0  France  44.0  72000.0        No
# 5  France  35.0  58000.0       Yes

# %%
df.iloc[[0,1,2]] #print information of index 0,1,2
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No

# %%
df.iloc[0:5] #print information from index 0 to 5
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes

# %%
df['Country'].iloc[0:4]# print only country column from index 0 to 4
# Out:
# 0     France
# 1      Spain
# 2    Germany
# 3      Spain
# Name: Country, dtype: object

# %%
df.columns # print all columns
# Out:
# Index(['Country', 'Age', 'Salary', 'Purchased'], dtype='object')

# %%
len(df) # total samples/ total rows
# Out:
# 10
